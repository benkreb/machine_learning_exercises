# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.columns
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice', 'ExterQual_TA', 'Foundation_PConc', 'KitchenQual_TA'],
#       dtype='object')

# %%
train.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0            6       1969          1969          663       663       1352
# 1            6       1920          1950         1012      1012       1012
# 2            5       1910          2006         1022      1022       1022
# 3            5       1973          1973         1656      1656       1656
# 4            6       1978          1978          918       918       1683
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 0         1             7           1         299     158000             1
# 1         1             6           1         308     118400             1
# 2         1             4           1         280      85000             1
# 3         2             8           2         506     135000             1
# 4         2             7           2         440     172500             1
#
#    Foundation_PConc  KitchenQual_TA
# 0                 0               1
# 1                 0               1
# 2                 0               1
# 3                 0               1
# 4                 0               1

# %%
train.shape
# Out:
# (765, 14)

# %%
test.shape
# Out:
# (329, 14)

# %%
model = LinearRegression()

# %%
X_train = train.drop('SalePrice', axis=1)
y_train = train.loc[:,'SalePrice']

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test = test.drop('SalePrice', axis=1)
y_test = test.loc[:,'SalePrice']

# %%
predictions = model.predict(X_test)

# %%
comparison = pd.DataFrame({"Actual Values": y_test,"Predictions": predictions})

# %%
comparison['Accuracy'] = (1-(abs(comparison['Actual Values'] - comparison['Predictions']))/(comparison['Actual Values']))

# %%
comparison.head()
# Out:
#    Actual Values    Predictions  Accuracy
# 0         118500   83380.944694  0.703637
# 1         154900  105974.149765  0.684146
# 2         133000  139238.138343  0.953097
# 3         115000  104982.049557  0.912887
# 4         154500  140473.360146  0.909213

# %%
train.corr()["SalePrice"].sort_values(ascending=False).head(10)
# Out:
# SalePrice           1.000000
# OverallQual         0.792263
# GrLivArea           0.712054
# GarageCars          0.658355
# GarageArea          0.621354
# 1stFlrSF            0.621057
# TotalBsmtSF         0.612205
# FullBath            0.597505
# TotRmsAbvGrd        0.573845
# Foundation_PConc    0.517222
# Name: SalePrice, dtype: float64
